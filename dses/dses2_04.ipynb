# %%
from pymongo import MongoClient as MC
import requests

# %%
uri="mongodb://strongadmin:rlehdeo2113!@ds023435.mlab.com:23435/storage"

# %%
client=MC(uri)

# %%
client.storage.collection_names()
# Out:
# ['users', 'system.indexes']

# %%
one_user={
    "name":"hanseo",
    "email":"sadsong4u",
    "phone":1025730937,
    "age":26,
    "gender":"m",
    "locale":"seoul",
}

# %%
db=client.storage
users=db.users
type(users)

#또는
#db=client["collections"]
#users=db["usesr"]
# Out:
# pymongo.collection.Collection

# %%
users.insert_one(one_user)

# %%
users.find_one()
# Out:
# {'_id': ObjectId('5afc14ad3146e4507c2ac176'),
#  'age': 26,
#  'email': 'sadsong4u',
#  'gender': 'm',
#  'locale': 'seoul',
#  'name': 'hanseo',
#  'phone': 1025730937}

# %%
many_user=[
    {
        "name":"hanseo",
        "email":"sadsong4u",
        "phone":1025730937,
        "age":26,
        "gender":"m",
        "locale":"seoul",
    },
    {
        "name":"jo",
        "email":"starkensin",
        "phone":413520927,
        "age":26,
        "gender":"m",
        "locale":"dangjin",
    },
]

# %%
users.insert_many(many_user)

# %%
q=[i for i in users.find({})]
q
# Out:
# [{'_id': ObjectId('5afc14ad3146e4507c2ac176'),
#   'age': 26,
#   'email': 'sadsong4u',
#   'gender': 'm',
#   'locale': 'seoul',
#   'name': 'hanseo',
#   'phone': 1025730937},
#  {'_id': ObjectId('5afc1b0f3146e4507c2ac177'),
#   'age': 26,
#   'email': 'sadsong4u',
#   'gender': 'm',
#   'locale': 'seoul',
#   'name': 'hanseo',
#   'phone': 1025730937},
#  {'_id': ObjectId('5afc1b0f3146e4507c2ac178'),
#   'age': 26,
#   'email': 'starkensin',
#   'gender': 'm',
#   'locale': 'dangjin',
#   'name': 'jo',
#   'phone': 413520927}]

# %%
# and operator
query={
    "locale":'seoul',
    "age":26
}
[i for i in users.find(query)]
# Out:
# [{'_id': ObjectId('5afc14ad3146e4507c2ac176'),
#   'age': 26,
#   'email': 'sadsong4u',
#   'gender': 'm',
#   'locale': 'seoul',
#   'name': 'hanseo',
#   'phone': 1025730937},
#  {'_id': ObjectId('5afc1b0f3146e4507c2ac177'),
#   'age': 26,
#   'email': 'sadsong4u',
#   'gender': 'm',
#   'locale': 'seoul',
#   'name': 'hanseo',
#   'phone': 1025730937}]

# %%
# where name in
query={
    "name":{
        "$in":["hanseo","jo"],
    },
}
[i for i in users.find(query)]
# Out:
# [{'_id': ObjectId('5afc14ad3146e4507c2ac176'),
#   'age': 26,
#   'email': 'sadsong4u',
#   'gender': 'm',
#   'locale': 'seoul',
#   'name': 'hanseo',
#   'phone': 1025730937},
#  {'_id': ObjectId('5afc1b0f3146e4507c2ac177'),
#   'age': 26,
#   'email': 'sadsong4u',
#   'gender': 'm',
#   'locale': 'seoul',
#   'name': 'hanseo',
#   'phone': 1025730937},
#  {'_id': ObjectId('5afc1b0f3146e4507c2ac178'),
#   'age': 26,
#   'email': 'starkensin',
#   'gender': 'm',
#   'locale': 'dangjin',
#   'name': 'jo',
#   'phone': 413520927}]

# %%
# or
query={
    "$or":[{"gender":"m"},{"age":26}],
}
[i for i in users.find(query)]
# Out:
# [{'_id': ObjectId('5afc14ad3146e4507c2ac176'),
#   'age': 26,
#   'email': 'sadsong4u',
#   'gender': 'm',
#   'locale': 'seoul',
#   'name': 'hanseo',
#   'phone': 1025730937},
#  {'_id': ObjectId('5afc1b0f3146e4507c2ac177'),
#   'age': 26,
#   'email': 'sadsong4u',
#   'gender': 'm',
#   'locale': 'seoul',
#   'name': 'hanseo',
#   'phone': 1025730937},
#  {'_id': ObjectId('5afc1b0f3146e4507c2ac178'),
#   'age': 26,
#   'email': 'starkensin',
#   'gender': 'm',
#   'locale': 'dangjin',
#   'name': 'jo',
#   'phone': 413520927}]

# %%
query={
    'age':{"$gte":30}
}
[i for i in users.find(query)]
# Out:
# []

# %%
query={
    "$or":[
        {'age':{"$lt":20}},
        {'age':{"$gte":30}}
    ]
}
[i for i in users.find(query)]
# Out:
# []

# %%
z_uri="https://api.zigbang.com/v3/items?detail=true&item_ids=[11449987,11522788,11553103,11574005,11359429,11540195,11548037,11554568,11300796,11348353,11581090,11330385,11484250,11188799,11588770,11596035,11420070,11435128,11544581,11447325,11596009,11603975,11539301,11571193,11376446,11599410,11526492,11449781,11592541,11590371,11571785,11438365,11590572,11328796,11405194,11511189,11553567,11535821,11442363,11385319,11391257,11284856,11560962,11595106,11379286,11443050,11531384,11380990,11249166,11497363,11565624,11528803,11575579,11559632,11396038,11537098,11549267,11297907,11592412,11339900]"

# %%
headers={
"Host": "api.zigbang.com",
"Connection": "keep-alive",
"Accept": "*/*",
"Origin": "https://www.zigbang.com",
"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.139 Safari/537.36",
"Referer": "https://www.zigbang.com/search/map?lat=37.54906&amp;lng=126.9705&amp;zoom=8&amp;GGKW=google",
"Accept-Encoding": "gzip, deflate, br",
"Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,ja;q=0.6",
}

# %%
response=requests.get(z_uri,headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
zigbang=client.storage["zigbang"]
response.text
# Out:
# '{"items":[{"title":"서울시 양천구 목동","header":false,"header_height":0,"item":{"id":11449987,"images":[{"index":0,"count":1,"url":"https://ic.zigbang.com/ic/users/2036074/photos/uploads/1d751f4c69c2ef4fbe6dc4f413c43d8324fefc90.4321260.JPG"},{"index":1,"count":2,"url":"https://ic.zigbang.com/ic/users/2036074/photos/uploads/890f9c6c4e677c257f13474e461565720d22b11f.4607720.JPG"},{"index":2,"count":3,"url":"https://ic.zigbang.com/ic/users/2036074/photos/uploads/436174b3f53e256f2b488f080c207384b461c60e.4622720.JPG"},{"index":3,"count":4,"url":"https://ic.zigbang.com/ic/users/2036074/photos/uploads/8605ac53d9b73ec1f6d09261c2a280df1ab4f40b.4255723.JPG"},{"index":4,"count":5,"url":"https://ic.zigbang.com/ic/users/2036074/photos/uploads/54df896e7bdf0456c53a8e4f21d5e361c1e2a9b1.4171498.JPG"},{"index":5,"count":6,"url":"https://ic.zigbang.com/ic/users/2036074/photos/uploads/674d6656af151f0c86236caa186c6fdac5300a40.4074683.JPG"},{"index":6,"count":7,"url":"https://ic.zigbang.com/ic/users/2036074/phot
# ...

# %%
response.json()
# Out:
# {'count_agent': 60,
#  'count_direct': 0,
#  'items': [{'header': False,
#    'header_height': 0,
#    'item': {'address1': '서울시 양천구 목동',
#     'address2': '522-9',
#     'address3': None,
#     'agent_address1': '서울특별시 영등포구 당산로20길 8-1 1층',
#     'agent_comment': '★다량의 매물을 보유하고 있는 원룸, 신축빌라, 오피스텔 전문 부동산입니다.\n\n★100% 실사, 실매물, 실가격을 원칙으로 하고 있습니다!!!\n\n★철저한 권리분석으로 고객님의 소중한 재산권을 지켜 드리겠습니다^^!!!\n\n★계약부터 이후 관리까지 확실하게 도움 드리겠습니다^^',
#     'agent_email': 'joyjoy8884@naver.com',
#     'agent_lat': 37.523323059082,
#     'agent_lng': 126.897026062012,
#     'agent_local1': '서울시',
#     'agent_local2': '영등포구',
#     'agent_mobile': '0507-1282-7463',
#     'agent_name': '조이부동산공인중개사(장혜리)',
#     'agent_no': 24688,
#     'agent_phone': '02-3667-8884',
#     'bjd_code': '1147010200',
#     'bonbun_code': '522',
#     'bubun_code': '9',
#     'building': None,
#     'building_type': '다세대건물',
#     'contract': '서울특별시',
#     'deposit': 19500,
# ...

# %%
lots_of=response.json()['items']
lots_of
# Out:
# [{'header': False,
#   'header_height': 0,
#   'item': {'address1': '서울시 양천구 목동',
#    'address2': '522-9',
#    'address3': None,
#    'agent_address1': '서울특별시 영등포구 당산로20길 8-1 1층',
#    'agent_comment': '★다량의 매물을 보유하고 있는 원룸, 신축빌라, 오피스텔 전문 부동산입니다.\n\n★100% 실사, 실매물, 실가격을 원칙으로 하고 있습니다!!!\n\n★철저한 권리분석으로 고객님의 소중한 재산권을 지켜 드리겠습니다^^!!!\n\n★계약부터 이후 관리까지 확실하게 도움 드리겠습니다^^',
#    'agent_email': 'joyjoy8884@naver.com',
#    'agent_lat': 37.523323059082,
#    'agent_lng': 126.897026062012,
#    'agent_local1': '서울시',
#    'agent_local2': '영등포구',
#    'agent_mobile': '0507-1282-7463',
#    'agent_name': '조이부동산공인중개사(장혜리)',
#    'agent_no': 24688,
#    'agent_phone': '02-3667-8884',
#    'bjd_code': '1147010200',
#    'bonbun_code': '522',
#    'bubun_code': '9',
#    'building': None,
#    'building_type': '다세대건물',
#    'contract': '서울특별시',
#    'deposit': 19500,
# ...

# %%
zigbang.insert_many(lots_of)

# %%
[i for i in zigbang.find({})]
# Out:
# [{'_id': ObjectId('5afc2d2a3146e4507c2ac17c'),
#   'header': False,
#   'header_height': 0,
#   'item': {'address1': '서울시 강서구 화곡동',
#    'address2': '963-22',
#    'address3': None,
#    'agent_address1': '서울특별시 강서구 화곡동 966-19',
#    'agent_comment': '',
#    'agent_email': 'jasmineis@hanmail.net',
#    'agent_lat': 37.54747,
#    'agent_lng': 126.849831,
#    'agent_local1': '서울시',
#    'agent_local2': '강서구',
#    'agent_mobile': '0507-1280-1503',
#    'agent_name': '목화공인중개사(김성춘)',
#    'agent_no': 0,
#    'agent_phone': '02-2606-8588',
#    'bjd_code': '1150010300',
#    'bonbun_code': '963',
#    'bubun_code': '22',
#    'building': None,
#    'building_type': '다세대건물',
#    'contract': '서울특별시',
#    'deposit': 1000,
#    'description': '위치좋고 깔끔하게 수리된 밝은 다가구 올라간 1층 입니다.즉시입주 가능하고 편의시설 풍부합니다.',
#    'description_og': '위치좋고 깔끔하게 수리된 밝은 다가구 올라간 1층 입니다.즉시입주 가능하고 편의시설 풍부합니다.',
#    'elevator': '없음',
#    'floor': '1층',
#    'floor_all': '2층',
#    'id': 11574005,
# ...

# %%
query={
    "$or":[ 
        {
             "item.deposit":{
                "$lt":1000
            }
        },
        {
            "item.rent":{"$lt":40}   
        }
    ]
}

len([i for i in zigbang.find(query)])
# Out:
# 44

# %%
# RDB 관점에서 뽑아내기
item_list=[item["item"]["deposit"] for item in zigbang.find({})]
item_list
# Out:
# [1000,
#  19500,
#  21000,
#  3000,
#  21000,
#  13500,
#  100,
#  1000,
#  18000,
#  29000,
#  12000,
#  23500,
#  8000,
#  500,
#  500,
#  13500,
#  23000,
#  1000,
#  3000,
#  1000,
#  15200,
#  16500,
#  20000,
#  18000,
#  10000,
#  500,
#  1000,
#  20000,
#  8000,
#  2000,
#  1500,
#  20000,
#  500,
#  1000,
#  500,
#  8000,
#  2000,
#  4000,
#  3000,
#  5500,
#  17500,
#  20000,
#  1000,
#  500,
#  16000,
#  1000,
#  2000,
#  21000,
#  23000,
#  22500,
#  10500,
#  5500,
#  3000,
#  6000,
#  4000,
#  500,
#  2000,
#  500,
#  8000,
#  500]

# %%
cursor=zigbang.aggregate([
    {
        "$group":{
            "_id":"$item.address1",
            "count":{"$sum":1},
        }
    }
])
for item in cursor:
    print(item)
# Out:
# {'_id': '서울시 강서구 가양동', 'count': 1}
# {'_id': '서울시 강서구 화곡동', 'count': 6}
# {'_id': '서울시 마포구 망원동', 'count': 1}
# {'_id': '서울시 마포구 상암동', 'count': 12}
# {'_id': '서울시 양천구 목2동', 'count': 3}
# {'_id': '서울시 강서구 염창동', 'count': 6}
# {'_id': '서울시 양천구 목동', 'count': 10}
# {'_id': '서울시 강서구 등촌동', 'count': 21}
